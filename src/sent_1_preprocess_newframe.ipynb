# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
# Defining directories
dir_path = Path.cwd().parent
prep_folder = dir_path.joinpath("data/prep")
s1_path = prep_folder.joinpath("sent1.parquet")

processed_folder = dir_path.joinpath("data/processed")
if not processed_folder.exists():
    processed_folder.mkdir(parents=True)

# %%
df = pd.read_parquet(s1_path)
df
# Out:
#                 date               long                 lat  \
# 0         2019-08-31  75.66669580000007   32.25107380000003
# 1         2019-08-31  75.66676390000003   32.25073910000003
# 2         2019-08-31  75.66686810000004   32.25026770000005
# 3         2019-08-31  75.66719240000003  32.249825100000066
# 4         2019-08-31  75.66729090000007   32.24962370000003
# ...              ...                ...                 ...
# 77813186  2021-11-19  76.46739500000007  32.928548300000045
# 77813187  2021-11-19  76.46765970000007   32.92851550000006
# 77813188  2021-11-19  76.46798620000004   32.93168870000005
# 77813189  2021-11-19  76.46884810000006   32.93124820000003
# 77813190  2021-11-19  76.47010840000007  32.932106600000054
#
#               species_names  vv_Descending  vh_Descending  vv_Ascending  \
# 0         Bambusoideae spp.          244.0          178.0           NaN
# 1         Bambusoideae spp.          324.0          129.0           NaN
# 2         Bambusoideae spp.          168.0          109.0           NaN
# 3         Bambusoideae spp.          257.0          123.0           NaN
# 4         Bambusoideae spp.          224.0           87.0           NaN
# ...                     ...            ...            ...           ...
# 77813186     Cedrus deodara           44.0           41.0           NaN
# 77813187     Cedrus deodara           43.0           26.0           NaN
# 77813188     Cedrus deodara           73.0           41.0           NaN
# 77813189     Cedrus deodara           88.0           45.0           NaN
# 77813190     Cedrus deodara           27.0           28.0           NaN
#
#           vh_Ascending
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 77813186           NaN
# 77813187           NaN
# 77813188           NaN
# 77813189           NaN
# 77813190           NaN
#
# [77813191 rows x 8 columns]

# %%
print(
    df['vh_Ascending'].isna().value_counts(),
df['vv_Ascending'].isna().value_counts(),
df['vh_Descending'].isna().value_counts(),
df['vv_Descending'].isna().value_counts()
)
# Out:
# vh_Ascending
# False    42127713
# True     35685478
# Name: count, dtype: int64 vv_Ascending
# False    42127723
# True     35685468
# Name: count, dtype: int64 vh_Descending
# True     42169016
# False    35644175
# Name: count, dtype: int64 vv_Descending
# True     42127736
# False    35685455
# Name: count, dtype: int64

# %%
#scaling fpr sentinel 1 
for band in ["vh_Ascending", "vv_Ascending", "vh_Descending", "vv_Descending"]:
    df[band] = 10 * np.log10(df[band])

# Extracting month and year
df["year"] = pd.to_datetime(df["date"]).dt.year
df["month"] = pd.to_datetime(df["date"]).dt.month
df.drop('date', axis=1, inplace=True)

# %%
print(
    df['vh_Ascending'].isna().value_counts(),
df['vv_Ascending'].isna().value_counts(),
df['vh_Descending'].isna().value_counts(),
df['vv_Descending'].isna().value_counts()
)
# Out:
# vh_Ascending
# False    42127713
# True     35685478
# Name: count, dtype: int64 vv_Ascending
# False    42127723
# True     35685468
# Name: count, dtype: int64 vh_Descending
# True     42169016
# False    35644175
# Name: count, dtype: int64 vv_Descending
# True     42127736
# False    35685455
# Name: count, dtype: int64

# %%
def make_s1_indices(df):
    #### SENTINEL 
    ## VV VH Ratio
    df['VV_VH_A'] = df['vv_Ascending'] / df['vh_Ascending']
    df['VV_VH_D'] = df['vv_Descending'] / df['vh_Descending']

    ## VH VV Ratio
    df['VH_VV_A'] = df['vh_Ascending'] / df['vv_Ascending']
    df['VH_VV_D'] = df['vh_Descending'] / df['vv_Descending']

    ## SAR Normalized Difference Vegetation Index 
    df['SAR_NDVI_A'] = (df['vh_Ascending'] - df['vv_Ascending']) / (df['vh_Ascending'] + df['vv_Ascending'])
    df['SAR_NDVI_D'] = (df['vh_Descending'] - df['vv_Descending']) / (df['vh_Descending'] + df['vv_Descending'])

    ## Difference Vegetation Index
    df['DVI_A'] = df['vh_Ascending'] - df['vv_Ascending']
    df['DVI_D'] = df['vh_Descending'] - df['vv_Descending']

    ## Sum Vegetation Index
    df['SVI_A'] = df['vh_Ascending'] + df['vv_Ascending']
    df['SVI_D'] = df['vh_Descending'] + df['vv_Descending']

    ## Relative Difference Vegetation Index (RDVI)
    df['RDVI_A'] = df['VH_VV_A'] - df['VV_VH_A']
    df['RDVI_D'] = df['VH_VV_D'] - df['VV_VH_D']

    ## Normalized Relative Difference Vegetation Index
    df['NRDVI_A'] = df['RDVI_A'] / (df['VH_VV_A'] + df['VV_VH_A'])
    df['NRDVI_D'] = df['RDVI_D'] / (df['VH_VV_D'] + df['VV_VH_D'])

    ## Sum of Squared Difference Vegetation Indexsrc/make_model_df.ipynb
    df['SSDVI_A'] = df['vh_Ascending'].pow(2) - df['vv_Ascending'].pow(2)
    df['SSDVI_D'] = df['vh_Descending'].pow(2) - df['vv_Descending'].pow(2)

    return df

df_indices = make_s1_indices(df)
df_indices
# Out:
#                        long                 lat      species_names  \
# 0         75.66669580000007   32.25107380000003  Bambusoideae spp.
# 1         75.66676390000003   32.25073910000003  Bambusoideae spp.
# 2         75.66686810000004   32.25026770000005  Bambusoideae spp.
# 3         75.66719240000003  32.249825100000066  Bambusoideae spp.
# 4         75.66729090000007   32.24962370000003  Bambusoideae spp.
# ...                     ...                 ...                ...
# 77813186  76.46739500000007  32.928548300000045     Cedrus deodara
# 77813187  76.46765970000007   32.92851550000006     Cedrus deodara
# 77813188  76.46798620000004   32.93168870000005     Cedrus deodara
# 77813189  76.46884810000006   32.93124820000003     Cedrus deodara
# 77813190  76.47010840000007  32.932106600000054     Cedrus deodara
#
#           vv_Descending  vh_Descending  vv_Ascending  vh_Ascending  year  \
# 0             23.873898      22.504200           NaN           NaN  2019
# 1             25.105450      21.105897           NaN           NaN  2019
# 2             22.253093      20.374265           NaN           NaN  2019
# 3             24.099331      20.899051           NaN           NaN  2019
# 4             23.502480      19.395193           NaN           NaN  2019
# ...                 ...            ...           ...           ...   ...
# 77813186      16.434527      16.127839           NaN           NaN  2021
# 77813187      16.334685      14.149733           NaN           NaN  2021
# 77813188      18.633229      16.127839           NaN           NaN  2021
# 77813189      19.444827      16.532125           NaN           NaN  2021
# 77813190      14.313638      14.471580           NaN           NaN  2021
#
#           month  VV_VH_A  ...  DVI_A     DVI_D  SVI_A      SVI_D  RDVI_A  \
# 0             8      NaN  ...    NaN -1.369698    NaN  46.378098     NaN
# 1             8      NaN  ...    NaN -3.999553    NaN  46.211347     NaN
# 2             8      NaN  ...    NaN -1.878828    NaN  42.627358     NaN
# 3             8      NaN  ...    NaN -3.200280    NaN  44.998382     NaN
# 4             8      NaN  ...    NaN -4.107288    NaN  42.897673     NaN
# ...         ...      ...  ...    ...       ...    ...        ...     ...
# 77813186     11      NaN  ...    NaN -0.306688    NaN  32.562365     NaN
# 77813187     11      NaN  ...    NaN -2.184951    NaN  30.484418     NaN
# 77813188     11      NaN  ...    NaN -2.505390    NaN  34.761067     NaN
# 77813189     11      NaN  ...    NaN -2.912702    NaN  35.976952     NaN
# 77813190     11      NaN  ...    NaN  0.157943    NaN  28.785218     NaN
#
#             RDVI_D  NRDVI_A   NRDVI_D  SSDVI_A     SSDVI_D
# 0        -0.118236      NaN -0.059015      NaN  -63.524000
# 1        -0.348809      NaN -0.171811      NaN -184.824732
# 2        -0.176646      NaN -0.087980      NaN  -80.089466
# 3        -0.285926      NaN -0.141524      NaN -144.007428
# 4        -0.386528      NaN -0.189753      NaN -176.193082
# ...            ...      ...       ...      ...         ...
# 77813186 -0.037677      NaN -0.018835      NaN   -9.986493
# 77813187 -0.288178      NaN -0.142616      NaN  -66.606962
# 77813188 -0.289804      NaN -0.143404      NaN  -87.090031
# 77813189 -0.325977      NaN -0.160866      NaN -104.790125
# 77813190  0.021948      NaN  0.010974      NaN    4.546414
#
# [77813191 rows x 25 columns]

# %% [markdown]
# ### Making Monthly Medians

# %%
index_cols = ["long", "lat", "year", "month", "species_names"]
#making monthlu medians
df_month_medians = (
    df_indices.groupby(index_cols)
    .median()
    .reset_index()
)

df_month_medians
# Out:
#                        long                 lat  year  month  \
# 0         75.66669580000007   32.25107380000003  2018      1
# 1         75.66669580000007   32.25107380000003  2018      2
# 2         75.66669580000007   32.25107380000003  2018      3
# 3         75.66669580000007   32.25107380000003  2018      4
# 4         75.66669580000007   32.25107380000003  2018      5
# ...                     ...                 ...   ...    ...
# 12508183  78.12624330000006  31.258713300000068  2024      8
# 12508184  78.12624330000006  31.258713300000068  2024      9
# 12508185  78.12624330000006  31.258713300000068  2024     10
# 12508186  78.12624330000006  31.258713300000068  2024     11
# 12508187  78.12624330000006  31.258713300000068  2024     12
#
#                   species_names  vv_Descending  vh_Descending  vv_Ascending  \
# 0             Bambusoideae spp.      23.174552      19.014211     22.405492
# 1             Bambusoideae spp.      23.242825      19.956352     22.166288
# 2             Bambusoideae spp.      21.281183      18.450980     23.676237
# 3             Bambusoideae spp.      22.552725      19.867717     23.384565
# 4             Bambusoideae spp.      22.848040      19.700091     22.878017
# ...                         ...            ...            ...           ...
# 12508183  Rhododendron arboreum      23.092960      19.633255     22.068678
# 12508184  Rhododendron arboreum      19.493900      19.030900     25.024271
# 12508185  Rhododendron arboreum      17.960884      17.548700     22.818354
# 12508186  Rhododendron arboreum      18.920946      16.720979     22.174839
# 12508187  Rhododendron arboreum      20.258463      18.381181     23.003340
#
#           vh_Ascending   VV_VH_A  ...     DVI_A     DVI_D      SVI_A  \
# 0            19.777236  1.104054  ... -2.111655 -4.160341  42.699330
# 1            21.461723  1.033557  ... -0.704565 -3.694342  43.628012
# 2            20.093502  1.179084  ... -3.582735 -2.830202  43.769740
# 3            19.956352  1.212000  ... -4.090376 -2.337480  44.595282
# 4            19.956352  1.116375  ... -2.467820 -3.147949  41.451342
# ...                ...       ...  ...       ...       ...        ...
# 12508183     21.522453  1.025432  ... -0.546225 -2.763381  43.591130
# 12508184     21.105897  1.156163  ... -3.446241 -2.238640  44.801507
# 12508185     20.740081  1.100403  ... -2.078273 -0.230907  43.558436
# 12508186     19.344985  1.129331  ... -2.461291 -2.199967  41.519824
# 12508187     19.418307  1.184505  ... -3.585033 -1.781400  42.421647
#
#               SVI_D    RDVI_A    RDVI_D   NRDVI_A   NRDVI_D     SSDVI_A  \
# 0         42.188762 -0.198301 -0.398812 -0.098667 -0.195303  -90.166242
# 1         43.371197 -0.065693 -0.344880 -0.032812 -0.169932  -30.259764
# 2         39.732163 -0.330660 -0.291276 -0.163029 -0.143803 -156.466199
# 3         41.528996 -0.386918 -0.218054 -0.189937 -0.108385 -174.572138
# 4         42.548131 -0.220619 -0.303061 -0.109644 -0.149384 -110.754026
# ...             ...       ...       ...       ...       ...         ...
# 12508183  43.201884 -0.049914 -0.255674 -0.024937 -0.126749  -23.920265
# 12508184  36.569602 -0.291233 -0.250365 -0.144097 -0.124213 -163.981665
# 12508185  35.348660 -0.191551 -0.024033 -0.095325 -0.012014  -90.421479
# 12508186  35.641925 -0.243852 -0.247841 -0.121029 -0.122980 -105.804204
# 12508187  38.276891 -0.340073 -0.172070 -0.167573 -0.085416 -152.316738
#
#              SSDVI_D
# 0        -175.427345
# 1        -156.206808
# 2        -111.066850
# 3        -100.525548
# 4        -132.122432
# ...              ...
# 12508183 -119.981582
# 12508184  -78.146481
# 12508185   -8.881958
# 12508186  -78.411074
# 12508187  -74.476914
#
# [12508188 rows x 25 columns]

# %% [markdown]
# ### Making Season Medians

# %%
# creating seasons
season_index_cols = ["long", "lat", "year", "season", "species_names"]


conds = [df_month_medians["month"].isin([3, 4, 5]), df_month_medians["month"].isin([10, 11, 12])]
opts = ["summer", "winter"]


df_month_medians["season"] = np.select(conds, opts, default="NA")
df_season_medians = df_month_medians[~(df_month_medians["season"] == "NA")]
 

df_season_medians = df_season_medians.groupby(season_index_cols).median().reset_index()
df_season_medians
# Out:
#                       long                 lat  year  season  \
# 0        75.66669580000007   32.25107380000003  2018  summer
# 1        75.66669580000007   32.25107380000003  2018  winter
# 2        75.66669580000007   32.25107380000003  2019  summer
# 3        75.66669580000007   32.25107380000003  2019  winter
# 4        75.66669580000007   32.25107380000003  2020  summer
# ...                    ...                 ...   ...     ...
# 2084693  78.12624330000006  31.258713300000068  2022  winter
# 2084694  78.12624330000006  31.258713300000068  2023  summer
# 2084695  78.12624330000006  31.258713300000068  2023  winter
# 2084696  78.12624330000006  31.258713300000068  2024  summer
# 2084697  78.12624330000006  31.258713300000068  2024  winter
#
#                  species_names  month  vv_Descending  vh_Descending  \
# 0            Bambusoideae spp.    4.0      22.552725      19.700091
# 1            Bambusoideae spp.   11.0      23.639657      20.492180
# 2            Bambusoideae spp.    4.0      23.856063      19.956352
# 3            Bambusoideae spp.   11.0      23.135292      20.770598
# 4            Bambusoideae spp.    4.0      23.268281      21.227070
# ...                        ...    ...            ...            ...
# 2084693  Rhododendron arboreum   11.0      20.606978      17.320957
# 2084694  Rhododendron arboreum    4.0      18.631598      16.617292
# 2084695  Rhododendron arboreum   11.0      20.718820      16.989700
# 2084696  Rhododendron arboreum    4.0      19.612070      18.042630
# 2084697  Rhododendron arboreum   11.0      18.920946      17.548700
#
#          vv_Ascending  vh_Ascending  ...     DVI_A     DVI_D      SVI_A  \
# 0           23.384565     19.956352  ... -3.582735 -2.830202  43.769740
# 1           22.741578     20.045554  ... -2.566007 -2.474472  44.383245
# 2           21.846914     20.530784  ... -1.316130 -3.943802  42.433853
# 3           24.087430     20.293079  ... -3.309932 -2.364695  44.380509
# 4           22.068259     20.086002  ... -2.090337 -4.028260  42.235219
# ...               ...           ...  ...       ...       ...        ...
# 2084693     22.648178     21.522883  ... -1.395479 -2.559417  44.171062
# 2084694     23.481170     19.839611  ... -3.641559 -0.741017  43.701799
# 2084695     22.944662     20.334238  ... -2.808266 -1.894584  43.711418
# 2084696     24.099331     20.606978  ... -2.713898 -1.569440  44.904501
# 2084697     22.818354     19.418307  ... -2.461291 -1.781400  42.421647
#
#              SVI_D    RDVI_A    RDVI_D   NRDVI_A   NRDVI_D     SSDVI_A  \
# 0        41.528996 -0.330660 -0.291276 -0.163029 -0.143803 -156.466199
# 1        44.359597 -0.245967 -0.228494 -0.122064 -0.113509 -107.481875
# 2        43.768323 -0.124348 -0.363376 -0.062054 -0.178761  -55.774555
# 3        43.905890 -0.313493 -0.215900 -0.154856 -0.107319 -140.641534
# 4        43.871136 -0.199344 -0.360037 -0.099106 -0.177096  -87.990981
# ...            ...       ...       ...       ...       ...         ...
# 2084693  37.472564 -0.123384 -0.276403 -0.061530 -0.136900  -63.214959
# 2084694  35.134575 -0.336719 -0.088761 -0.165855 -0.044337 -158.956064
# 2084695  37.708520 -0.264081 -0.197352 -0.130904 -0.098199 -119.971852
# 2084696  37.654700 -0.237433 -0.163345 -0.117889 -0.081177 -124.516749
# 2084697  35.641925 -0.243852 -0.172070 -0.121029 -0.085416 -105.804204
#
#             SSDVI_D
# 0       -111.066850
# 1       -107.537649
# 2       -172.613601
# 3       -103.918188
# 4       -171.256533
# ...             ...
# 2084693  -97.142729
# 2084694  -28.777109
# 2084695  -64.619521
# 2084696  -60.586361
# 2084697  -74.476914
#
# [2084698 rows x 26 columns]

# %% [markdown]
# There are no NaNs in the resulting frame because its created from monthly medians

# %% [markdown]
# ### Splitting Testing and Training
# All data from 2024 will be assigned for testing and data from 2018 - 2023 (6 years) will be used for training.

# %%
sent1_train_season_medians = df_season_medians[df_season_medians['year']!=2024]
sent1_test_season_medians = df_season_medians[df_season_medians['year']==2024]


sent1_train_season_medians = sent1_train_season_medians.drop(["month"], axis=1)
sent1_test_season_medians = sent1_test_season_medians.drop(["month"], axis=1)

sent1_train_season_medians
# Out:
#                       long                 lat  year  season  \
# 0        75.66669580000007   32.25107380000003  2018  summer
# 1        75.66669580000007   32.25107380000003  2018  winter
# 2        75.66669580000007   32.25107380000003  2019  summer
# 3        75.66669580000007   32.25107380000003  2019  winter
# 4        75.66669580000007   32.25107380000003  2020  summer
# ...                    ...                 ...   ...     ...
# 2084691  78.12624330000006  31.258713300000068  2021  winter
# 2084692  78.12624330000006  31.258713300000068  2022  summer
# 2084693  78.12624330000006  31.258713300000068  2022  winter
# 2084694  78.12624330000006  31.258713300000068  2023  summer
# 2084695  78.12624330000006  31.258713300000068  2023  winter
#
#                  species_names  vv_Descending  vh_Descending  vv_Ascending  \
# 0            Bambusoideae spp.      22.552725      19.700091     23.384565
# 1            Bambusoideae spp.      23.639657      20.492180     22.741578
# 2            Bambusoideae spp.      23.856063      19.956352     21.846914
# 3            Bambusoideae spp.      23.135292      20.770598     24.087430
# 4            Bambusoideae spp.      23.268281      21.227070     22.068259
# ...                        ...            ...            ...           ...
# 2084691  Rhododendron arboreum      23.242825      21.789769     23.443923
# 2084692  Rhododendron arboreum      20.043214      17.781513     23.856063
# 2084693  Rhododendron arboreum      20.606978      17.320957     22.648178
# 2084694  Rhododendron arboreum      18.631598      16.617292     23.481170
# 2084695  Rhododendron arboreum      20.718820      16.989700     22.944662
#
#          vh_Ascending   VV_VH_A  ...     DVI_A     DVI_D      SVI_A  \
# 0           19.956352  1.179084  ... -3.582735 -2.830202  43.769740
# 1           20.045554  1.130519  ... -2.566007 -2.474472  44.383245
# 2           20.530784  1.064105  ... -1.316130 -3.943802  42.433853
# 3           20.293079  1.168957  ... -3.309932 -2.364695  44.380509
# 4           20.086002  1.104880  ... -2.090337 -4.028260  42.235219
# ...               ...       ...  ...       ...       ...        ...
# 2084691     20.043214  1.182678  ... -3.553042 -2.485054  43.429704
# 2084692     21.522883  1.085827  ... -1.929358 -2.289904  45.459747
# 2084693     21.522883  1.063837  ... -1.395479 -2.559417  44.171062
# 2084694     19.839611  1.182774  ... -3.641559 -0.741017  43.701799
# 2084695     20.334238  1.140720  ... -2.808266 -1.894584  43.711418
#
#              SVI_D    RDVI_A    RDVI_D   NRDVI_A   NRDVI_D     SSDVI_A  \
# 0        41.528996 -0.330660 -0.291276 -0.163029 -0.143803 -156.466199
# 1        44.359597 -0.245967 -0.228494 -0.122064 -0.113509 -107.481875
# 2        43.768323 -0.124348 -0.363376 -0.062054 -0.178761  -55.774555
# 3        43.905890 -0.313493 -0.215900 -0.154856 -0.107319 -140.641534
# 4        43.871136 -0.199344 -0.360037 -0.099106 -0.177096  -87.990981
# ...            ...       ...       ...       ...       ...         ...
# 2084691  45.032594 -0.334547 -0.259086 -0.164246 -0.128468 -152.540861
# 2084692  35.976952 -0.164869 -0.191256 -0.082156 -0.095194  -90.465334
# 2084693  37.472564 -0.123384 -0.276403 -0.061530 -0.136900  -63.214959
# 2084694  35.134575 -0.336719 -0.088761 -0.165855 -0.044337 -158.956064
# 2084695  37.708520 -0.264081 -0.197352 -0.130904 -0.098199 -119.971852
#
#             SSDVI_D
# 0       -111.066850
# 1       -107.537649
# 2       -172.613601
# 3       -103.918188
# 4       -171.256533
# ...             ...
# 2084691 -103.770884
# 2084692 -106.838739
# 2084693  -97.142729
# 2084694  -28.777109
# 2084695  -64.619521
#
# [1786884 rows x 25 columns]

# %% [markdown]
# ### Widening the frame

# %% [markdown]
# #### Widening Train

# %%
sent1_train_season_medians_wide = sent1_train_season_medians.pivot(index=['long', 'lat', 'year','species_names'], columns=['season']).reset_index()
new_cols = ["".join(x) for x in sent1_train_season_medians_wide.columns]
sent1_train_season_medians_wide.columns = new_cols
sent1_train_season_medians_wide
# Out:
#                      long                 lat  year          species_names  \
# 0       75.66669580000007   32.25107380000003  2018      Bambusoideae spp.
# 1       75.66669580000007   32.25107380000003  2019      Bambusoideae spp.
# 2       75.66669580000007   32.25107380000003  2020      Bambusoideae spp.
# 3       75.66669580000007   32.25107380000003  2021      Bambusoideae spp.
# 4       75.66669580000007   32.25107380000003  2022      Bambusoideae spp.
# ...                   ...                 ...   ...                    ...
# 893437  78.12624330000006  31.258713300000068  2019  Rhododendron arboreum
# 893438  78.12624330000006  31.258713300000068  2020  Rhododendron arboreum
# 893439  78.12624330000006  31.258713300000068  2021  Rhododendron arboreum
# 893440  78.12624330000006  31.258713300000068  2022  Rhododendron arboreum
# 893441  78.12624330000006  31.258713300000068  2023  Rhododendron arboreum
#
#         vv_Descendingsummer  vv_Descendingwinter  vh_Descendingsummer  \
# 0                 22.552725            23.639657            19.700091
# 1                 23.856063            23.135292            19.956352
# 2                 23.268281            23.263359            21.227070
# 3                 24.927604            24.248816            19.777236
# 4                 24.149733            22.787536            20.453230
# ...                     ...                  ...                  ...
# 893437            24.899585            21.450173            22.922561
# 893438            21.172713            21.895621            18.450980
# 893439            20.863598            23.242825            19.138139
# 893440            20.043214            20.606978            17.781513
# 893441            18.631598            20.718820            16.617292
#
#         vh_Descendingwinter  vv_Ascendingsummer  vv_Ascendingwinter  ...  \
# 0                 20.492180           23.384565           22.741578  ...
# 1                 20.770598           21.846914           24.087430  ...
# 2                 19.558451           22.068259           22.833012  ...
# 3                 20.024829           22.430380           22.405492  ...
# 4                 19.684829           23.242825           23.933544  ...
# ...                     ...                 ...                 ...  ...
# 893437            18.317562           26.345883           26.085735  ...
# 893438            19.714503           22.845933           23.283796  ...
# 893439            21.789769           23.112055           23.443923  ...
# 893440            17.320957           23.856063           22.648178  ...
# 893441            16.989700           23.481170           22.944662  ...
#
#         RDVI_Dsummer  RDVI_Dwinter  NRDVI_Asummer  NRDVI_Awinter  \
# 0          -0.291276     -0.228494      -0.163029      -0.122064
# 1          -0.363376     -0.215900      -0.062054      -0.154856
# 2          -0.360037     -0.360521      -0.099106      -0.161609
# 3          -0.398256     -0.301932      -0.125368      -0.121973
# 4          -0.348859     -0.233890      -0.113490      -0.208427
# ...              ...           ...            ...            ...
# 893437     -0.179344     -0.317698      -0.133248      -0.112385
# 893438     -0.245430     -0.231446      -0.059729      -0.196282
# 893439     -0.233344     -0.259086      -0.130513      -0.164246
# 893440     -0.191256     -0.276403      -0.082156      -0.061530
# 893441     -0.088761     -0.197352      -0.165855      -0.130904
#
#         NRDVI_Dsummer  NRDVI_Dwinter  SSDVI_Asummer  SSDVI_Awinter  \
# 0           -0.143803      -0.113509    -156.466199    -107.481875
# 1           -0.178761      -0.107319     -55.774555    -140.641534
# 2           -0.177096      -0.177402     -87.990981    -151.061373
# 3           -0.195294      -0.149274    -123.071242    -108.863796
# 4           -0.171835      -0.116153    -107.109181    -196.687173
# ...               ...            ...            ...            ...
# 893437      -0.089297      -0.156882    -165.262369    -139.104165
# 893438      -0.121801      -0.114956     -61.603105    -177.903651
# 893439      -0.115886      -0.128468    -124.691840    -152.540861
# 893440      -0.095194      -0.136900     -90.465334     -63.214959
# 893441      -0.044337      -0.098199    -158.956064    -119.971852
#
#         SSDVI_Dsummer  SSDVI_Dwinter
# 0         -111.066850    -107.537649
# 1         -172.613601    -103.918188
# 2         -171.256533    -163.082568
# 3         -203.050827    -157.318045
# 4         -173.599348    -107.662974
# ...               ...            ...
# 893437     -94.545533    -136.152344
# 893438    -113.293761     -98.577484
# 893439    -103.136725    -103.770884
# 893440    -106.838739     -97.142729
# 893441     -28.777109     -64.619521
#
# [893442 rows x 44 columns]

# %% [markdown]
# ##### Widen Test

# %%
sent1_test_season_medians_wide = sent1_test_season_medians.pivot(index=['long', 'lat', 'year', 'species_names'], columns=['season']).reset_index()
new_cols = ["".join(x) for x in sent1_test_season_medians_wide.columns]
sent1_test_season_medians_wide.columns = new_cols
sent1_test_season_medians_wide
# Out:
#                      long                 lat  year          species_names  \
# 0       75.66669580000007   32.25107380000003  2024      Bambusoideae spp.
# 1       75.66676390000003   32.25073910000003  2024      Bambusoideae spp.
# 2       75.66686810000004   32.25026770000005  2024      Bambusoideae spp.
# 3       75.66719240000003  32.249825100000066  2024      Bambusoideae spp.
# 4       75.66729090000007   32.24962370000003  2024      Bambusoideae spp.
# ...                   ...                 ...   ...                    ...
# 148902  78.12497830000007   31.25865170000003  2024  Rhododendron arboreum
# 148903  78.12522000000007  31.258880000000033  2024  Rhododendron arboreum
# 148904  78.12614830000007  31.258660000000077  2024  Rhododendron arboreum
# 148905  78.12618260000005   31.25882800000005  2024  Rhododendron arboreum
# 148906  78.12624330000006  31.258713300000068  2024  Rhododendron arboreum
#
#         vv_Descendingsummer  vv_Descendingwinter  vh_Descendingsummer  \
# 0                 22.329961            23.283796            20.855999
# 1                 23.710679            23.786145            19.777236
# 2                 24.082400            23.820170            21.139434
# 3                 21.702617            23.463530            20.713199
# 4                 25.352941            23.563249            22.088770
# ...                     ...                  ...                  ...
# 148902            18.888946            18.692317            16.334685
# 148903            17.708520            17.923917            16.627578
# 148904            19.411484            19.242793            17.198242
# 148905            19.912261            18.384382            17.993405
# 148906            19.612070            18.920946            18.042630
#
#         vh_Descendingwinter  vv_Ascendingsummer  vv_Ascendingwinter  ...  \
# 0                 18.947904           22.922561           23.829795  ...
# 1                 19.955244           20.844843           19.280017  ...
# 2                 21.449505           22.718416           23.069685  ...
# 3                 20.934217           23.260264           23.891661  ...
# 4                 21.461280           22.510769           23.018103  ...
# ...                     ...                 ...                 ...  ...
# 148902            17.132556           23.207470           22.411509  ...
# 148903            16.213949           22.671717           23.344351  ...
# 148904            16.627578           23.424227           23.057820  ...
# 148905            17.428607           22.355284           21.180166  ...
# 148906            17.548700           24.099331           22.818354  ...
#
#         RDVI_Dsummer  RDVI_Dwinter  NRDVI_Asummer  NRDVI_Awinter  \
# 0          -0.199947     -0.321819      -0.127756      -0.165662
# 1          -0.377909     -0.266552      -0.238637      -0.106794
# 2          -0.262839     -0.236903      -0.077496      -0.099564
# 3          -0.171177     -0.199373      -0.056007      -0.100159
# 4          -0.186049     -0.221375      -0.118311      -0.118761
# ...              ...           ...            ...            ...
# 148902     -0.170429     -0.181020      -0.083127      -0.092637
# 148903     -0.214484     -0.145798      -0.075293      -0.155308
# 148904     -0.287797     -0.191686      -0.090191      -0.089627
# 148905     -0.128113     -0.245241      -0.067839      -0.099945
# 148906     -0.163345     -0.172070      -0.117889      -0.121029
#
#         NRDVI_Dsummer  NRDVI_Dwinter  SSDVI_Asummer  SSDVI_Awinter  \
# 0           -0.099478      -0.158866    -137.101837    -163.194938
# 1           -0.185669      -0.132108    -170.728100     -71.635497
# 2           -0.130299      -0.117629     -76.977260     -95.889959
# 3           -0.085277      -0.099195     -55.821320    -104.322354
# 4           -0.092069      -0.110016    -119.092017    -109.853732
# ...               ...            ...            ...            ...
# 148902      -0.084907      -0.090117     -82.164870     -88.577731
# 148903      -0.106631      -0.072706     -65.420747    -165.360064
# 148904      -0.142432      -0.094224     -90.786151     -87.431108
# 148905      -0.063926      -0.121709     -72.741127     -81.024611
# 148906      -0.081177      -0.085416    -124.516749    -105.804204
#
#         SSDVI_Dsummer  SSDVI_Dwinter
# 0          -98.101772    -150.438419
# 1         -182.401575    -133.415633
# 2         -133.902116    -116.844349
# 3          -72.590927     -99.906539
# 4          -99.370167    -105.925533
# ...               ...            ...
# 148902     -59.254315     -55.170010
# 148903     -70.973345     -43.825039
# 148904     -93.516283     -82.358827
# 148905     -57.003766     -88.151803
# 148906     -60.586361     -74.476914
#
# [148907 rows x 44 columns]

# %%
for col in sent1_train_season_medians_wide.columns:
    print(pd.Series(sent1_train_season_medians_wide[col].isna().value_counts()))
# Out:
# long
# False    893442
# Name: count, dtype: int64
# lat
# False    893442
# Name: count, dtype: int64
# year
# False    893442
# Name: count, dtype: int64
# species_names
# False    893442
# Name: count, dtype: int64
# vv_Descendingsummer
# False    893442
# Name: count, dtype: int64
# vv_Descendingwinter
# False    893442
# Name: count, dtype: int64
# vh_Descendingsummer
# False    893442
# Name: count, dtype: int64
# vh_Descendingwinter
# False    893442
# Name: count, dtype: int64
# vv_Ascendingsummer
# False    893442
# Name: count, dtype: int64
# vv_Ascendingwinter
# False    893442
# Name: count, dtype: int64
# vh_Ascendingsummer
# False    893442
# Name: count, dtype: int64
# vh_Ascendingwinter
# False    893442
# Name: count, dtype: int64
# VV_VH_Asummer
# False    893442
# Name: count, dtype: int64
# VV_VH_Awinter
# False    893442
# Name: count, dtype: int64
# VV_VH_Dsummer
# False    893442
# Name: count, dtype: int64
# VV_VH_Dwinter
# False    893442
# Name: count, dtype: int64
# VH_VV_Asummer
# False    893442
# Name: count, dtype: int64
# VH_VV_Awinter
# False    893442
# Name: count, dtype: int64
# VH_VV_Dsummer
# False    893442
# Name: count, dtype: int64
# VH_VV_Dwinter
# False    893442
# Name: count, dtype: int64
# SAR_NDVI_Asummer
# False    893442
# Name: count, dtype: int64
# SAR_NDVI_Awinter
# False    893442
# Name: count, dtype: int64
# SAR_NDVI_Dsummer
# False    893442
# Name: count, dtype: int64
# SAR_NDVI_Dwinter
# False    893442
# Name: count, dtype: int64
# DVI_Asummer
# False    893442
# Name: count, dtype: int64
# DVI_Awinter
# False    893442
# Name: count, dtype: int64
# DVI_Dsummer
# False    893442
# Name: count, dtype: int64
# DVI_Dwinter
# False    893442
# Name: count, dtype: int64
# SVI_Asummer
# False    893442
# Name: count, dtype: int64
# SVI_Awinter
# False    893442
# Name: count, dtype: int64
# SVI_Dsummer
# False    893442
# Name: count, dtype: int64
# SVI_Dwinter
# False    893442
# Name: count, dtype: int64
# RDVI_Asummer
# False    893442
# Name: count, dtype: int64
# RDVI_Awinter
# False    893442
# Name: count, dtype: int64
# RDVI_Dsummer
# False    893442
# Name: count, dtype: int64
# RDVI_Dwinter
# False    893442
# Name: count, dtype: int64
# NRDVI_Asummer
# False    893442
# Name: count, dtype: int64
# NRDVI_Awinter
# False    893442
# Name: count, dtype: int64
# NRDVI_Dsummer
# False    893442
# Name: count, dtype: int64
# NRDVI_Dwinter
# False    893442
# Name: count, dtype: int64
# SSDVI_Asummer
# False    893442
# Name: count, dtype: int64
# SSDVI_Awinter
# False    893442
# Name: count, dtype: int64
# SSDVI_Dsummer
# False    893442
# Name: count, dtype: int64
# SSDVI_Dwinter
# False    893442
# Name: count, dtype: int64

# %% [markdown]
# ### Exporting Frames

# %%
sent_1_month_medians_path = processed_folder.joinpath("sent_1_month_medians.parquet")
sent_1_season_medians_path = processed_folder.joinpath("sent_1_season_medians.parquet")

sent1_train_season_medians_widened_path = processed_folder.joinpath("sent1_train_season_medians_widened.parquet")
sent1_test_season_medians_widened_path = processed_folder.joinpath("sent1_test_season_medians_widened.parquet")

# %%
df_month_medians.to_parquet(sent_1_month_medians_path, index=False)
df_season_medians.to_parquet(sent_1_season_medians_path, index=False)

# %%
sent1_train_season_medians_wide.to_parquet(sent1_train_season_medians_widened_path, index=False)
sent1_test_season_medians_wide.to_parquet(sent1_test_season_medians_widened_path, index=False)
